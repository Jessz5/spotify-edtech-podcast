# %% [markdown]
# # Spotify EdTech Podcast
# >Using the Spotify API to gather podcast data for shows and episodes related to the search term "EdTech."

# %% [markdown]
# ### Install Spotipy
# >A lightweight Python library that serves as a client for the Spotify Web API

# %%
# !pip install spotipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spotipy in /usr/local/lib/python3.10/dist-packages (2.23.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from spotipy) (4.5.5)
# Requirement already satisfied: requests>=2.25.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (2.27.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from spotipy) (1.26.15)
# Requirement already satisfied: async-timeout>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25.0->spotipy) (3.4)

# %% [markdown]
# ### Search for Podcasts Related to the Term 'EdTech'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# Set your Spotify API credentials
client_id = 'xxxxxx'
client_secret = 'xxxxxx'

# Set up the Spotify client with client credentials
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# Enter the term to search here
search_term = 'EdTech'

# Initialize variables
offset = 0
limit = 50
all_shows = []

# Retrieve all shows with the specified term
while True:
    result = sp.search(q=search_term, type='show', market='US', limit=limit, offset=offset)
    shows = result['shows']['items']
    all_shows.extend(shows)
    
    total_shows = result['shows']['total']
    offset += limit
    
    if offset >= total_shows:
        break

# Process the search results
if all_shows:
    show_data = []
    for show in all_shows:
        show_data.append({
            'Show_ID': show['id'],
            'Show_Name': show['name'],
            'Show_Description': show['description']
        })
    podcasts = pd.DataFrame(show_data)
else:
    print('No shows found.')

# %%
podcasts
# Out:
#                     Show_ID                              Show_Name  \
# 0    51MrXc7hJQBE2WJf2g4aWN                 WSJ Tech News Briefing
# 1    5oOBPrlO68dNZXen9Kxg0e                     The Edtech Podcast
# 2    4PeMaMtSPgIBYXhxoqAyik                        Edtech Insiders
# 3    6hQYpQb9AfbEReRgrqZ4ov                       Marketplace Tech
# 4    0qjdB2LMPLMPxOq05ewboe  Easy EdTech Podcast with Monica Burns
# ..                      ...                                    ...
# 158  3dRRDQ0RQnfPg5FKRFZfLL                   EdTech Greatest Hits
# 159  1T73QZmw3j0L9O7rkHV4Aa                Project Medtech Podcast
# 160  6ChrFs99h3GptBK6Dg9OLe                           EdTech Cubed
# 161  1i2s4TFjhgW3WLyT6Yi9Fp                           Medtech Talk
# 162  63ghn2JFuMT50qtq9rZMsH                             EdTechNext
#
#                                       Show_Description
# 0    Tech News Briefing is your guide to what peopl...
# 1    The Edtech Podcast gets behind the personaliti...
# 2    At Edtech Insiders, we interview founders, inv...
# 3    Monday through Friday, Marketplace demystifies...
# 4    Monica Burns from the popular EdTech blog Clas...
# ..                                                 ...
# 158  EdTech Greatest Hits  is a round up of the mos...
# 159  Join us as we sit down with leading experts in...
# 160  EdTech Cubed is an unconditional space for con...
# 161  A weekly conversation with the innovators who ...
# 162  EdTechNext is a podcast showcasing the hottest...
#
# [163 rows x 3 columns]

# %%
show_list = list(podcasts['Show_ID'])
show_list
# Out:
# ['51MrXc7hJQBE2WJf2g4aWN',
#  '5oOBPrlO68dNZXen9Kxg0e',
#  '4PeMaMtSPgIBYXhxoqAyik',
#  '6hQYpQb9AfbEReRgrqZ4ov',
#  '0qjdB2LMPLMPxOq05ewboe',
#  '25mc5JcXq2dv2XQPA1eFnA',
#  '1tPxtbTTzVhPYCUGgWjKW8',
#  '4vk2MfVMEAuOnTWUOz6lnE',
#  '4sATASDUkdvcDnlkdlkw88',
#  '1BekdFqQUp0IqXrVsSJQcq',
#  '57wZcoxW8oNs5Mq7WZfTs7',
#  '6J7h66ARN6q9RFxpBGKizs',
#  '6p346qTB82PYUv5XW8ZcLu',
#  '3I5RPNDkZ6dQzWaboqBcqi',
#  '3ISqoRP0Jtyx5qb1AeksCX',
#  '2Uadk5CLLnr1VpkW8IUzDG',
#  '4KIiefg33DSzHjsXXLwtCf',
#  '09CNaauiBoMvkCRPhEJYfU',
#  '3jShkLd4nDgSTsUvLrRBNx',
#  '2zeUDPme3Xl0ZiecTuunYa',
#  '4isqXhnUoGnzzZt6smQjRs',
#  '1iwcjlgreRD0nJxgtdwMLx',
#  '07RYEoRzFDOVyWDYVz1zk4',
#  '03YPUjcXPDta8mGghik8Fw',
#  '5CdZxK0O7LnVMp5n2bIbm5',
#  '1VgpwxORbKhiyFJ4QkKOt2',
#  '1PfZoZ8kYBn2kbMWrOnAH6',
#  '7G7vjwnMr1KpZ15SL0FEB0',
#  '3HuaFrlBEilA7ztAVA89B0',
#  '0vWTdKoricMHNuRmZd2iFi',
#  '0I2G8IUWRUJ68pDPmz4SkJ',
#  '0l1ZsEe6V3z0ACMLks8Pk4',
#  '2tqFrkflmhpGLqxvL1kpkQ',
#  '1FqXtfD8f9jmAxpMHrGGdU',
#  '0V6c4QVjMueSLYxZlkt4CD',
#  '6Y1CLZU5Mz6VfD2i7njIq0',
#  '6XRZx6uO06yr2olPyQbBD1',
#  '38w4XDrE2U7hfvoj2Ri3s9',
#  '54c4HT8qp29AttIidZ12CU',
#  '4NKhXNQxJCBiKHkGFkoZ3C',
#  '76h8fh9KK3boiMrQ340lV4',
#  '3bqFkMhO2IiwWtlaEMCPjT',
#  '4WmXEDaa3jGkF3hifxStFh',
#  '52ktGt8lRPH50S9Gspnmq3',
#  '29eeC2kUEpYkDIYO4Bj0Qr',
#  '3LByOzN6vUwc85cfopvJfj',
#  '0rXHgcS5UFOMgVQFUqAK69',
#  '6ab1DScbgONSkPm7q3w5iG',
#  '6eMEJGLVvjzUaBlb9L54ZR',
#  '1XtSnvR9YHJQJH3JG1iGfH',
#  '7JAYxWui1hwPu1Zcs5lACH',
#  '4jm5gkQrTEbBdP9oMDdTu4',
#  '5iFd27SONgo2b8NOUuj006',
#  '4NkW4HG6vUtkLoCaD7lqT5',
#  '18GZrBkQ3bROuPW3yMIbLr',
#  '5MQ90M7TTK1KiYAnVEyHaO',
#  '4TEZ78QhgfQuELNBWie58f',
#  '4hj5livsN2oUq8Js79JRjm',
#  '3ct5FNqesNdgga0npDDrbY',
#  '2noNJlX8c7PSdwIP7Oe08O',
#  '25ct43uQeZH9Zypoo5oyc4',
#  '09X4Nn247yvpdV3qufQ5dL',
#  '4g6ZBIKMkDSufQLkA3dkea',
#  '6SMYOJ0WEykKw4Bivf2qEI',
#  '0eOXScAcCVZnyBis0FgI7d',
#  '1lLlNiOSnYgvGFdGsumdA6',
#  '54pWXGsp6PUo4SRi3OQfHu',
#  '10RebgtgVmzRBDJ39wm4Ug',
#  '5TRRTynzNv4AGhc7mJMyCA',
#  '27WTtiklv16rTeGqQelM3s',
#  '3qjEX1U85YWics5ObCSjBm',
#  '6dXMcLeAozrV59iwQgXAuc',
#  '48q64kXhMcpi4LngbwzDTy',
#  '3RQqQ4N94o3i5vzkIkMtwN',
#  '60pvNpmbjwAAYoXobYWZ0W',
#  '47MLxQriHWzaSSe0Rd2T6G',
#  '2qf9enuV6E4dy5jZT8va5Q',
#  '4gnYrbU2A5MYOCaOQFO8mL',
#  '5Omg7s9kRYFgt4jEynpdoL',
#  '6l6QQjUgq25CLfjGtRk1Ss',
#  '7d29j7sHEdUeOo1q56fZA0',
#  '07HhLnHxF9DjSPSpepDiD0',
#  '01uxIzDJBkjexF0oSCG9ia',
#  '18ZXusD67X5bsI6T9qS90F',
#  '06DOU2eJ2yx5drVdEnd5qa',
#  '5oOB2nG1dw5RGTBqaZR0hq',
#  '5ZTik0n1bl0yeCjgq3gqL6',
#  '3TeRpcYlmICdeNYd6cvYJX',
#  '7mDyVayXXqeMYZna5gStHf',
#  '0qzKlJQsI0IOpSvtdy2YKO',
#  '6KhWdPDxR4B90JUeigfXBY',
#  '1q5VRgo0NXBr6bwMoC9LbF',
#  '4zirup9xVgtXpsI6r76WGv',
#  '5MU6QIQ7ZwqbgeCeJgJpUo',
#  '3ExbR0sBbe0y7chpgc8DlS',
#  '0Vc053AFzWEDtdbQescz76',
#  '4HKlQLsN9zAXcFKEDiFuL7',
#  '2686Id4rQKMnUXWKAk0lmi',
#  '2kH7lmVvfP97yx1hsbZl45',
#  '1j3btqq3jpChumi0sDK28R',
#  '44sK1Zm6Elgr91ulT00kMh',
#  '20RrgvAKu5Ksg9zl6kdSd9',
#  '2dX6ZBJeZRDzf2MJpvHxWL',
#  '0I3S1vMG98iOp8IK4maf2z',
#  '3ukPxztBFzp9KbNgyuvUur',
#  '0ZQIDM1Z62TzZx6qkbSntK',
#  '4yC3HK1uOQWSH6ikuiUTds',
#  '47rJanqe8TBORRXTt6EjGE',
#  '17sZqRdW4IY7XJULc1Ordw',
#  '3m4IrreRbXACZWVNnXEFKZ',
#  '51sHbjOURXaXwPzKB0CpeS',
#  '1Py8YAy68GTuLsbcp3K8f1',
#  '6JKhEFeD06jNaukVBsQUcr',
#  '3WXMYzO9fy3v8EYlK9sWaN',
#  '3utp8uZaeuPPJbFTsbWXiQ',
#  '748KvYVBZ4U4LG7KFdSnV9',
#  '10f7e8vqVyINpYKypm52PS',
#  '5gIhthDDHG5cP9GGycwzeF',
#  '5ct86dQNCKzRPSN5BvNIZF',
#  '11mhmDShZN85uMaE9aRlhn',
#  '0wKf80nNh1tu4ks0m2vC1T',
#  '6AprhbJICANPF9TNbqoOS9',
#  '2tkEBdcbKmurlTxRbMO1Jz',
#  '7BcqEc61slYlJDig6QrsdD',
#  '7CtvbQoCZO1E9nqOf4Lazu',
#  '1mTXW9diqttWhEX9sSyWTV',
#  '450k39yUSUfmQ5GcHDlfnw',
#  '2jjxMaf00TlgajwqOd9wH5',
#  '7oR4Y8nxRaSdEmBXNjb08g',
#  '4WTRQFUrvsAyQqtk9BCGBM',
#  '4yXtcmnWk6TSO1wvu2kE5o',
#  '7kb5rjTDpqHFC2wUmTBA5S',
#  '3qOgk0E25kPjKVtWsfmS3R',
#  '4feRwYbrYiE934SHajWPen',
#  '1Vht4EFpBSCWMjYqQ71FmP',
#  '6engT8d9zSWKrq9YbG3koU',
#  '0VFt0CSB7dOXrQ1h5UQgaM',
#  '5rfeCD5Xr71KEBbaw1sJOi',
#  '2yIrIfOtyOicyj2gpSWMvG',
#  '5GWzfagEYF0CsUQILxHNEX',
#  '5CGv43KoDGBG1wyr4VHc5X',
#  '4Yu6zOOj6OWwd21hPeVWxt',
#  '6kOdgt0MjSAeWx2vEcN4HA',
#  '3uqF9iOw1wze7O1vTRpgGV',
#  '4lUqFpahx5eB6zuJLKIaJD',
#  '0E91dgNpKzC3HQkiltcbqo',
#  '3JT2JWzSQkjwApJUM1zMZ2',
#  '3buwf0eZR0AKesRodi5Ky4',
#  '7G35aIQjiaEfldTWqBNPBd',
#  '1BoR8xMkzT3oA4lnQi1ULD',
#  '0EG8aywKIscMkckWIgyYqi',
#  '12fMkiJY1saMnP1lrbPRgk',
#  '6qsWUSG0zaHDPUtSGoPwpP',
#  '1OK5LfChGS000docd0pEAh',
#  '5WtlYDtvzos3gvIrzTsL01',
#  '3cE1cwT1P2kOHkzQa3a0m3',
#  '7pOeYLQ6Uf6JYKaOshuK09',
#  '3d4rXeFvFrCN4HNMKrOvj3',
#  '3dRRDQ0RQnfPg5FKRFZfLL',
#  '1T73QZmw3j0L9O7rkHV4Aa',
#  '6ChrFs99h3GptBK6Dg9OLe',
#  '1i2s4TFjhgW3WLyT6Yi9Fp',
#  '63ghn2JFuMT50qtq9rZMsH']

# %% [markdown]
# ### Search for Episodes in Podcasts Related to the Term 'EdTech'

# %%
# Retrieve episodes for all shows in the show_list
all_episodes = []
for show_id in show_list:
    offset = 0
    limit = 50
    while True:
        result = sp.show_episodes(show_id, market='US', limit=limit, offset=offset)
        episodes = result['items']
        for episode in episodes:
            episode_data = {
                'Episode_Show_ID': show_id,
                'Episode_ID': episode['id'],
                'Episode_Name': episode['name'],
                'Episode_Description': episode['description'],
                'Episode_Duration (ms)': episode['duration_ms'],
                'Episode_Release Date': episode['release_date']
            }
            all_episodes.append(episode_data)

        total_episodes = result['total']
        offset += limit

        if offset >= total_episodes:
            break

# Process the episode data
if all_episodes:
    episodes_df = pd.DataFrame(all_episodes)
else:
    print('No episodes found.')

# %%
episodes_df
# Out:
#               Episode_Show_ID              Episode_ID  \
# 0      51MrXc7hJQBE2WJf2g4aWN  0vKc893EjWoQ4IkuCQg31w
# 1      51MrXc7hJQBE2WJf2g4aWN  784BQgBkH9FH57A2X3qLo1
# 2      51MrXc7hJQBE2WJf2g4aWN  7EGOubiDSDhIOdk5d44k8m
# 3      51MrXc7hJQBE2WJf2g4aWN  60xrY4M1woJmH4tWqVIn6O
# 4      51MrXc7hJQBE2WJf2g4aWN  29FZMoutxSglganFmuv2dq
# ...                       ...                     ...
# 23134  1i2s4TFjhgW3WLyT6Yi9Fp  3KBvEhtfvSWtdYT3OJQ6pW
# 23135  1i2s4TFjhgW3WLyT6Yi9Fp  6gFSVz7V62aDARjWlx5X1i
# 23136  1i2s4TFjhgW3WLyT6Yi9Fp  3amnmCHOKtmJxcjoIR7OPF
# 23137  1i2s4TFjhgW3WLyT6Yi9Fp  0ESULEDAKuRsVp4NdMIDri
# 23138  63ghn2JFuMT50qtq9rZMsH  2t4z9QTTIxRAwvknXeRgpi
#
#                                             Episode_Name  \
# 0      The Executive Keeping Tesla Rolling Isn’t Elon...
# 1      TikTok Still Fills Teens' Feeds With Dark Content
# 2      OpenAI Boss Calls for AI Safety Standards at S...
# 3      Elon Musk Is Running Twitter Like SpaceX. Will...
# 4      Apple Takes New Approach With Mixed-Reality He...
# ...                                                  ...
# 23134       Vivo Capital Building Bridges Across Pacific
# 23135          NEA’s Klein Sees Opportunities in Medtech
# 23136      Holaira’s Wahr Sees Success Ahead for Medtech
# 23137  Intersect ENT Keeps Pace in Tech Rich Silicon ...
# 23138                          EdTechNext- The Glide App
#
#                                      Episode_Description  \
# 0      Tesla’s CFO Zach Kirkhorn has a reputation for...
# 1      Montana’s Governor signed the county’s first s...
# 2       Sam Altman, CEO of OpenAI the company behind ...
# 3      Elon Musk is trying to run his social media co...
# 4      Elon Musk has named a new CEO to replace him a...
# ...                                                  ...
# 23134  Vivo Capital, fresh off raising $750 million f...
# 23135  Justin Klein, MD, general partner at NEA and c...
# 23136  Dennis Wahr, MD, CEO of Holaira Inc. and co-ch...
# 23137  Intersect ENT CEO Lisa Earnhardt shares her pe...
# 23138  Learn about the Glide app and how you can crea...
#
#        Episode_Duration (ms) Episode_Release Date
# 0                     742452           2023-05-19
# 1                     721188           2023-05-18
# 2                     712542           2023-05-17
# 3                     722337           2023-05-16
# 4                     709799           2023-05-15
# ...                      ...                  ...
# 23134                1209783           2015-04-09
# 23135                1579886           2015-03-26
# 23136                1388304           2015-03-26
# 23137                1200744           2015-03-18
# 23138                 246944           2019-04-08
#
# [23139 rows x 6 columns]

# %% [markdown]
# ### Merge Podcast and Episode DataFrames

# %%
merged_df = podcasts.merge(episodes_df, left_on='Show_ID', right_on='Episode_Show_ID', how='left')
merged_df
# Out:
#                       Show_ID               Show_Name  \
# 0      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 1      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 2      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 3      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 4      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# ...                       ...                     ...
# 23134  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23135  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23136  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23137  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23138  63ghn2JFuMT50qtq9rZMsH              EdTechNext
#
#                                         Show_Description  \
# 0      Tech News Briefing is your guide to what peopl...
# 1      Tech News Briefing is your guide to what peopl...
# 2      Tech News Briefing is your guide to what peopl...
# 3      Tech News Briefing is your guide to what peopl...
# 4      Tech News Briefing is your guide to what peopl...
# ...                                                  ...
# 23134  A weekly conversation with the innovators who ...
# 23135  A weekly conversation with the innovators who ...
# 23136  A weekly conversation with the innovators who ...
# 23137  A weekly conversation with the innovators who ...
# 23138  EdTechNext is a podcast showcasing the hottest...
#
#               Episode_Show_ID              Episode_ID  \
# 0      51MrXc7hJQBE2WJf2g4aWN  0vKc893EjWoQ4IkuCQg31w
# 1      51MrXc7hJQBE2WJf2g4aWN  784BQgBkH9FH57A2X3qLo1
# 2      51MrXc7hJQBE2WJf2g4aWN  7EGOubiDSDhIOdk5d44k8m
# 3      51MrXc7hJQBE2WJf2g4aWN  60xrY4M1woJmH4tWqVIn6O
# 4      51MrXc7hJQBE2WJf2g4aWN  29FZMoutxSglganFmuv2dq
# ...                       ...                     ...
# 23134  1i2s4TFjhgW3WLyT6Yi9Fp  3KBvEhtfvSWtdYT3OJQ6pW
# 23135  1i2s4TFjhgW3WLyT6Yi9Fp  6gFSVz7V62aDARjWlx5X1i
# 23136  1i2s4TFjhgW3WLyT6Yi9Fp  3amnmCHOKtmJxcjoIR7OPF
# 23137  1i2s4TFjhgW3WLyT6Yi9Fp  0ESULEDAKuRsVp4NdMIDri
# 23138  63ghn2JFuMT50qtq9rZMsH  2t4z9QTTIxRAwvknXeRgpi
#
#                                             Episode_Name  \
# 0      The Executive Keeping Tesla Rolling Isn’t Elon...
# 1      TikTok Still Fills Teens' Feeds With Dark Content
# 2      OpenAI Boss Calls for AI Safety Standards at S...
# 3      Elon Musk Is Running Twitter Like SpaceX. Will...
# 4      Apple Takes New Approach With Mixed-Reality He...
# ...                                                  ...
# 23134       Vivo Capital Building Bridges Across Pacific
# 23135          NEA’s Klein Sees Opportunities in Medtech
# 23136      Holaira’s Wahr Sees Success Ahead for Medtech
# 23137  Intersect ENT Keeps Pace in Tech Rich Silicon ...
# 23138                          EdTechNext- The Glide App
#
#                                      Episode_Description  \
# 0      Tesla’s CFO Zach Kirkhorn has a reputation for...
# 1      Montana’s Governor signed the county’s first s...
# 2       Sam Altman, CEO of OpenAI the company behind ...
# 3      Elon Musk is trying to run his social media co...
# 4      Elon Musk has named a new CEO to replace him a...
# ...                                                  ...
# 23134  Vivo Capital, fresh off raising $750 million f...
# 23135  Justin Klein, MD, general partner at NEA and c...
# 23136  Dennis Wahr, MD, CEO of Holaira Inc. and co-ch...
# 23137  Intersect ENT CEO Lisa Earnhardt shares her pe...
# 23138  Learn about the Glide app and how you can crea...
#
#        Episode_Duration (ms) Episode_Release Date
# 0                     742452           2023-05-19
# 1                     721188           2023-05-18
# 2                     712542           2023-05-17
# 3                     722337           2023-05-16
# 4                     709799           2023-05-15
# ...                      ...                  ...
# 23134                1209783           2015-04-09
# 23135                1579886           2015-03-26
# 23136                1388304           2015-03-26
# 23137                1200744           2015-03-18
# 23138                 246944           2019-04-08
#
# [23139 rows x 9 columns]

# %%
merged_df = merged_df.drop('Episode_Show_ID', axis=1)
merged_df
# Out:
#                       Show_ID               Show_Name  \
# 0      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 1      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 2      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 3      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# 4      51MrXc7hJQBE2WJf2g4aWN  WSJ Tech News Briefing
# ...                       ...                     ...
# 23134  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23135  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23136  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23137  1i2s4TFjhgW3WLyT6Yi9Fp            Medtech Talk
# 23138  63ghn2JFuMT50qtq9rZMsH              EdTechNext
#
#                                         Show_Description  \
# 0      Tech News Briefing is your guide to what peopl...
# 1      Tech News Briefing is your guide to what peopl...
# 2      Tech News Briefing is your guide to what peopl...
# 3      Tech News Briefing is your guide to what peopl...
# 4      Tech News Briefing is your guide to what peopl...
# ...                                                  ...
# 23134  A weekly conversation with the innovators who ...
# 23135  A weekly conversation with the innovators who ...
# 23136  A weekly conversation with the innovators who ...
# 23137  A weekly conversation with the innovators who ...
# 23138  EdTechNext is a podcast showcasing the hottest...
#
#                    Episode_ID  \
# 0      0vKc893EjWoQ4IkuCQg31w
# 1      784BQgBkH9FH57A2X3qLo1
# 2      7EGOubiDSDhIOdk5d44k8m
# 3      60xrY4M1woJmH4tWqVIn6O
# 4      29FZMoutxSglganFmuv2dq
# ...                       ...
# 23134  3KBvEhtfvSWtdYT3OJQ6pW
# 23135  6gFSVz7V62aDARjWlx5X1i
# 23136  3amnmCHOKtmJxcjoIR7OPF
# 23137  0ESULEDAKuRsVp4NdMIDri
# 23138  2t4z9QTTIxRAwvknXeRgpi
#
#                                             Episode_Name  \
# 0      The Executive Keeping Tesla Rolling Isn’t Elon...
# 1      TikTok Still Fills Teens' Feeds With Dark Content
# 2      OpenAI Boss Calls for AI Safety Standards at S...
# 3      Elon Musk Is Running Twitter Like SpaceX. Will...
# 4      Apple Takes New Approach With Mixed-Reality He...
# ...                                                  ...
# 23134       Vivo Capital Building Bridges Across Pacific
# 23135          NEA’s Klein Sees Opportunities in Medtech
# 23136      Holaira’s Wahr Sees Success Ahead for Medtech
# 23137  Intersect ENT Keeps Pace in Tech Rich Silicon ...
# 23138                          EdTechNext- The Glide App
#
#                                      Episode_Description  \
# 0      Tesla’s CFO Zach Kirkhorn has a reputation for...
# 1      Montana’s Governor signed the county’s first s...
# 2       Sam Altman, CEO of OpenAI the company behind ...
# 3      Elon Musk is trying to run his social media co...
# 4      Elon Musk has named a new CEO to replace him a...
# ...                                                  ...
# 23134  Vivo Capital, fresh off raising $750 million f...
# 23135  Justin Klein, MD, general partner at NEA and c...
# 23136  Dennis Wahr, MD, CEO of Holaira Inc. and co-ch...
# 23137  Intersect ENT CEO Lisa Earnhardt shares her pe...
# 23138  Learn about the Glide app and how you can crea...
#
#        Episode_Duration (ms) Episode_Release Date
# 0                     742452           2023-05-19
# 1                     721188           2023-05-18
# 2                     712542           2023-05-17
# 3                     722337           2023-05-16
# 4                     709799           2023-05-15
# ...                      ...                  ...
# 23134                1209783           2015-04-09
# 23135                1579886           2015-03-26
# 23136                1388304           2015-03-26
# 23137                1200744           2015-03-18
# 23138                 246944           2019-04-08
#
# [23139 rows x 8 columns]

# %% [markdown]
# ### Convert the Merged DataFrame into a CSV File

# %%
merged_df.to_csv("spotify_EdTech_podcast_data.csv", index=False)
